# %%
import pandas as pd
import numpy as np
import os
import glob
import import_ipynb
import functions_notebook
# Out:
# importing Jupyter notebook from functions_notebook.ipynb

# %% [markdown]
# ### General Checks

# %%
# !ls -lh ../data/data_gage_height_combined/
# Out:
# total 8018064
# -rw-------@ 1 msleckman  GS\Domain Users    46M Jun 29 12:57 clean_data_05515500_00065_uv.csv
# -rw-------@ 1 msleckman  GS\Domain Users    30M Jun 29 12:57 clean_data_05516665_00065_uv.csv
# -rw-------@ 1 msleckman  GS\Domain Users    46M Jun 29 12:57 clean_data_05517000_00065_uv.csv
# -rw-------@ 1 msleckman  GS\Domain Users    46M Jun 29 12:57 clean_data_05517500_00065_uv.csv
# -rw-------@ 1 msleckman  GS\Domain Users    42M Jun 29 12:57 clean_data_05518000_00065_uv.csv
# -rw-------@ 1 msleckman  GS\Domain Users   439K Jun 29 12:57 clean_data_05520500_00065_dv.csv
# -rw-------@ 1 msleckman  GS\Domain Users    46M Jun 29 12:57 clean_data_05520500_00065_uv.csv
# -rw-------@ 1 msleckman  GS\Domain Users    43M Jun 29 12:57 clean_data_05524500_00065_uv.csv
# -rw-------@ 1 msleckman  GS\Domain Users   439K Jun 29 12:57 clean_data_05525000_00065_dv.csv
# -rw-------@ 1 msleckman  GS\Domain Users    45M Jun 29 12:57 clean_data_05525000_00065_uv.csv
# ...

# %%
### function outputs two items list of file names and list of dataframe items
gheight_names, gheight_dfs = functions_notebook.read_in_csv_gp(
    base_folder = '../data/data_gage_height_combined/',
    file_string = '*',
    dtype_dict = {'site_no':str})
# Out:
# clean_data_05570910_00065_uv.csv
# Location:../data/data_gage_height_combined/clean_data_05570910_00065_uv.csv
#   source   site_no        date             date_time tz_cd  parameter_cd  \
# 0   NWIS  05570910  2007-10-01  2007-10-01T06:00:00Z   UTC            65
# 1   NWIS  05570910  2007-10-01  2007-10-01T06:15:00Z   UTC            65
# 2   NWIS  05570910  2007-10-01  2007-10-01T06:30:00Z   UTC            65
# 3   NWIS  05570910  2007-10-01  2007-10-01T06:45:00Z   UTC            65
# 4   NWIS  05570910  2007-10-01  2007-10-01T07:00:00Z   UTC            65
#
#             freq  stat_name  sensor_description  result_va units  remark_cd  \
# 0  instantaneous        NaN                 NaN   1.438586     m        NaN
# 1  instantaneous        NaN                 NaN   1.438586     m        NaN
# 2  instantaneous        NaN                 NaN   1.441634     m        NaN
# 3  instantaneous        NaN                 NaN   1.438586     m        NaN
# ...

# %%
## Combined the dataframe here since it represents one metric
gheight_full_df = pd.concat(gheight_dfs)
gheight_full_df.columns
# Out:
# Index(['source', 'site_no', 'date', 'date_time', 'tz_cd', 'parameter_cd',
#        'freq', 'stat_name', 'sensor_description', 'result_va', 'units',
#        'remark_cd', 'method_cd', 'result_qualifier_cd', 'filename'],
#       dtype='object')

# %%
### Specifics
functions_notebook.print_df_specs(gheight_full_df.reset_index())
# Out:
#  clean_data_05570910_00065_uv.csv
# <bound method DataFrame.info of           index source   site_no        date             date_time tz_cd  \
# 0             0   NWIS  05570910  2007-10-01  2007-10-01T06:00:00Z   UTC
# 1             1   NWIS  05570910  2007-10-01  2007-10-01T06:15:00Z   UTC
# 2             2   NWIS  05570910  2007-10-01  2007-10-01T06:30:00Z   UTC
# 3             3   NWIS  05570910  2007-10-01  2007-10-01T06:45:00Z   UTC
# 4             4   NWIS  05570910  2007-10-01  2007-10-01T07:00:00Z   UTC
# ...         ...    ...       ...         ...                   ...   ...
# 38893505   6569   NWIS  05550001  2020-12-27                   NaN   UTC
# 38893506   6570   NWIS  05550001  2020-12-28                   NaN   UTC
# 38893507   6571   NWIS  05550001  2020-12-29                   NaN   UTC
# 38893508   6572   NWIS  05550001  2020-12-30                   NaN   UTC
# 38893509   6573   NWIS  05550001  2020-12-31                   NaN   UTC
#
# ...

# %%
counter = 1

z = gheight_full_df
    
print(z.iloc[:,0:5].head())
    
filename = z['filename'].iloc[0]
    
print('\n',counter,'.', filename)

if (z.columns.str.contains('date').any() == True):
    z.sort_values('date')
    functions_notebook.check_date(z, date_col = 'date')
else:
    print(f'No date column in {filename}')
    print('columns: ', z.columns)
        
counter = counter + 1
# Out:
#   source   site_no       date             date_time tz_cd
# 0   NWIS  05570910 2007-10-01  2007-10-01T06:00:00Z   UTC
# 1   NWIS  05570910 2007-10-01  2007-10-01T06:15:00Z   UTC
# 2   NWIS  05570910 2007-10-01  2007-10-01T06:30:00Z   UTC
# 3   NWIS  05570910 2007-10-01  2007-10-01T06:45:00Z   UTC
# 4   NWIS  05570910 2007-10-01  2007-10-01T07:00:00Z   UTC
#
#  1 . clean_data_05570910_00065_uv.csv
#
# original date col type: datetime64[ns]
#
#  date col type after pandas conversion: datetime64[ns]
# 175027    date format e.g. 2013-02-04 correct
# Name: date, dtype: object
#
# End of month dates:
#  ['10-31' '12-31' '01-31' '03-31' '05-31' '07-31' '08-31']
#
# Leap year dates:
#  ['2008-02-29T00:00:00.000000000' '2012-02-29T00:00:00.000000000'
#  '2016-02-29T00:00:00.000000000' '2020-02-29T00:00:00.000000000']
#
# Earliest date: 2005-10-01 00:00:00
# Latest date: 2021-01-01 00:00:00

# %%
counter = 1

print(f'\n{counter}. {z.filename[0]}')
cols = z.columns

for col in cols:
    print('   ', z[col].name,'  - dtype:', z[col].dtypes)
    if z[col].dtypes == 'O':
        functions_notebook.check_whitespace(df_col = z[col])
        
    if (z[col].dtypes == 'float64') or (z[col].dtypes == 'int64'):
        functions_notebook.calc_metrics(df_col = z[col])
        
    else: 
        pass
        
    counter = counter + 1
    
    print(f'\n   > whitespace scan complete for {z.filename[0]}')
# Out:
# 1. 0    clean_data_05570910_00065_uv.csv
# 0    clean_data_05584500_00065_uv.csv
# 0    clean_data_05536123_00065_dv.csv
# 0    clean_data_05541710_00065_dv.csv
# 0    clean_data_05586100_00065_dv.csv
#                    ...
# 0    clean_data_05536890_00065_uv.csv
# 0    clean_data_05579500_00065_uv.csv
# 0    clean_data_05540500_00065_dv.csv
# 0    clean_data_05578250_00065_dv.csv
# 0    clean_data_05550001_00065_dv.csv
# Name: filename, Length: 158, dtype: object
#     source   - dtype: object
#        unique str values are  ['NWIS']
#
#    > whitespace scan complete for 0    clean_data_05570910_00065_uv.csv
# 0    clean_data_05584500_00065_uv.csv
# 0    clean_data_05536123_00065_dv.csv
# 0    clean_data_05541710_00065_dv.csv
# 0    clean_data_05586100_00065_dv.csv
#                    ...
# 0    clean_data_05536890_00065_uv.csv
# 0    clean_data_05579500_00065_uv.csv
# 0    clean_data_05540500_00065_dv.csv
# 0    clean_data_05578250_00065_dv.csv
# ...
